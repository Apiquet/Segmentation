# %% [markdown]
# ## If in Colab

# %%
in_colab = True
floatType = 32
last_data_idx = -1

# %%
import tensorflow as tf
if in_colab:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
if floatType == 16:
    tf.keras.backend.set_floatx('float16')
# Out:
# Mounted at /content/drive

# %%
if in_colab:
    import sys
    data_dir = "/content/drive/MyDrive/data/"
    VOC2012_path = data_dir
    tracker_path = data_dir
    sys.path.append(tracker_path)
    ssd_weights_path = data_dir + "ssd_weights_epoch_0380.h5"
    checkpoint_filepath = data_dir + "weights/"
else:
    data_dir = "../data/"
    VOC2012_path = data_dir + "VOCdevkit/"
    tracker_path = "../Tracking_SSD_ReID/"
    ssd_weights_path = data_dir + "ssd_weights_epoch_0380.h5"
    checkpoint_filepath = data_dir + "segmentation_weights/"

# %% [markdown]
# ## Import model

# %%
from models.FCN8 import FCN8
model = FCN8(tracker_ssd_path = tracker_path, 
             ssd_weights_path = ssd_weights_path,
             floatType = floatType,
             n_classes=3)

# %% [markdown]
# ## Prepare VOC2012 segmentation data

# %%
from data_management.VOC2012Manager import VOC2012Manager

manager = VOC2012Manager(floatType = floatType)
targets = ["person", "dog"]
images, gt_annotations, filenames_png, original_shapes =\
    manager.load_and_prepare_data(
        VOC2012_path=VOC2012_path,
        width_height=(300, 300,),
        n_samples_to_show=5,
        targets=targets,
        last_data_idx=last_data_idx)
# Out:
#   0%|          | 0/2912 [00:00<?, ?it/s]
# Loading images and annotations...
# 100%|██████████| 2912/2912 [26:26<00:00,  1.84it/s]
# Convert to tensor...
#   1%|          | 7/1084 [00:00<00:15, 69.75it/s]
# Done
# Images shape: (1084, 300, 300, 3), annotations shape: (1084, 300, 300, 1)
# Reshape gt from (300, 300, 1) to (300, 300, n_classes)
# 100%|██████████| 1084/1084 [00:01<00:00, 588.14it/s]
# Images shape: (1084, 300, 300, 3), annotations shape: (1084, 300, 300, 3)
# Examples:

# %%
train_ratio = 0.7
batch_size = 32
train_dataset, val_dataset = manager.tensorf2TFData(images, gt_annotations, train_ratio, batch_size)

# %%
# # verify train val shapes
# for train_img, train_annot in train_dataset:
#     break
# for val_img, val_annot in val_dataset:
#     break
# print(f"Train images shape: {train_img.shape}, train annotations shape: {train_annot.shape}")
# print(f"Val images shape: {val_img.shape}, Val annotations shape: {val_annot.shape}")

# %% [markdown]
# ## Train model

# %%
sgd = tf.keras.optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True)

model.compile(loss='categorical_crossentropy',
              optimizer=sgd,
              metrics=['accuracy'])

# %%
# number of training images
train_count = images.shape[0] * train_ratio

# number of validation images
validation_count = images.shape[0] * (1 - train_ratio)

epochs = 100

steps_per_epoch = train_count//batch_size
validation_steps = validation_count//batch_size

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %%
history = model.fit(train_dataset, steps_per_epoch=steps_per_epoch,
                    validation_data=val_dataset, validation_steps=validation_steps,
                    epochs=epochs, callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.5228 - accuracy: 0.8216 - val_loss: 0.5091 - val_accuracy: 0.8232
# Epoch 2/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.5075 - accuracy: 0.8280 - val_loss: 0.4983 - val_accuracy: 0.8279
# Epoch 3/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.5080 - accuracy: 0.8251 - val_loss: 0.5466 - val_accuracy: 0.8083
# Epoch 4/100
# 23/23 [==============================] - 44s 2s/step - loss: 0.5276 - accuracy: 0.8153 - val_loss: 0.5438 - val_accuracy: 0.8024
# Epoch 5/100
# 23/23 [==============================] - 44s 2s/step - loss: 0.4985 - accuracy: 0.8308 - val_loss: 0.5023 - val_accuracy: 0.8302
# Epoch 6/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.5054 - accuracy: 0.8279 - val_loss: 0.5102 - val_accuracy: 0.8201
# Epoch 7/100
# 23/23 [==============================] - 44s 2s/step - loss: 0.5124 - accuracy: 0.8230 - val_loss: 0.4983 - val_accuracy: 0.8268
# Epoch 8/100
# 23/23 [==============================] - 44s 2s/step - loss: 0.5314 - accuracy: 0.8153 - val_loss: 0.5289 - val_accuracy: 0.8172
# Epoch 9/100
# 23/23 [==============================] - 44s 2s/step - loss: 0.5141 - accuracy: 0.8167 - val_loss: 0.5040 - val_accuracy: 0.8193
# Epoch 10/100
# 23/23 [==============================] - 44s 2s/step - loss: 0.4875 - accuracy: 0.8328 - val_loss: 0.5169 - val_accuracy: 0.8362
# Epoch 11/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.4814 - accuracy: 0.8334 - val_loss: 0.5183 - val_accuracy: 0.8224
# Epoch 12/100
# 23/23 [==============================] - 44s 2s/step - loss: 0.4898 - accuracy: 0.8237 - val_loss: 0.4771 - val_accuracy: 0.8245
# Epoch 13/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.4918 - accuracy: 0.8210 - val_loss: 0.4931 - val_accuracy: 0.8203
# Epoch 14/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.5267 - accuracy: 0.8178 - val_loss: 0.5151 - val_accuracy: 0.8140
# Epoch 15/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.5100 - accuracy: 0.8232 - val_loss: 0.4787 - val_accuracy: 0.8342
# Epoch 16/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.4945 - accuracy: 0.8259 - val_loss: 0.5297 - val_accuracy: 0.8188
# Epoch 17/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.5178 - accuracy: 0.8172 - val_loss: 0.4753 - val_accuracy: 0.8277
# Epoch 18/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.5122 - accuracy: 0.8175 - val_loss: 0.4885 - val_accuracy: 0.8307
# Epoch 19/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.4862 - accuracy: 0.8220 - val_loss: 0.4930 - val_accuracy: 0.8005
# Epoch 20/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.5328 - accuracy: 0.8225 - val_loss: 0.4877 - val_accuracy: 0.8231
# Epoch 21/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.4953 - accuracy: 0.8212 - val_loss: 0.4943 - val_accuracy: 0.8194
# Epoch 22/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.4819 - accuracy: 0.8242 - val_loss: 0.4954 - val_accuracy: 0.8182
# Epoch 23/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.4896 - accuracy: 0.8180 - val_loss: 0.4682 - val_accuracy: 0.8296
# Epoch 24/100
# 23/23 [==============================] - 44s 2s/step - loss: 0.4871 - accuracy: 0.8200 - val_loss: 0.5362 - val_accuracy: 0.8071
# Epoch 25/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.4733 - accuracy: 0.8256 - val_loss: 0.4544 - val_accuracy: 0.8238
# Epoch 26/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.4518 - accuracy: 0.8267 - val_loss: 0.4482 - val_accuracy: 0.8169
# Epoch 27/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.4277 - accuracy: 0.8281 - val_loss: 0.4501 - val_accuracy: 0.8094
# Epoch 28/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.4238 - accuracy: 0.8272 - val_loss: 0.4131 - val_accuracy: 0.8273
# Epoch 29/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.4402 - accuracy: 0.8309 - val_loss: 0.4136 - val_accuracy: 0.8246
# Epoch 30/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.4133 - accuracy: 0.8239 - val_loss: 0.3931 - val_accuracy: 0.8328
# Epoch 31/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.4054 - accuracy: 0.8300 - val_loss: 0.4063 - val_accuracy: 0.8239
# Epoch 32/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.4223 - accuracy: 0.8225 - val_loss: 0.4265 - val_accuracy: 0.8295
# Epoch 33/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.3959 - accuracy: 0.8303 - val_loss: 0.3519 - val_accuracy: 0.8412
# Epoch 34/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.3934 - accuracy: 0.8263 - val_loss: 0.3710 - val_accuracy: 0.8407
# Epoch 35/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.3719 - accuracy: 0.8359 - val_loss: 0.3690 - val_accuracy: 0.8536
# Epoch 36/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.3801 - accuracy: 0.8298 - val_loss: 0.3743 - val_accuracy: 0.8283
# Epoch 37/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.3738 - accuracy: 0.8297 - val_loss: 0.3726 - val_accuracy: 0.8291
# Epoch 38/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.3580 - accuracy: 0.8394 - val_loss: 0.3742 - val_accuracy: 0.8214
# Epoch 39/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.3535 - accuracy: 0.8376 - val_loss: 0.3383 - val_accuracy: 0.8471
# Epoch 40/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.3661 - accuracy: 0.8305 - val_loss: 0.3953 - val_accuracy: 0.8321
# Epoch 41/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.3395 - accuracy: 0.8421 - val_loss: 0.3550 - val_accuracy: 0.8364
# Epoch 42/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.3584 - accuracy: 0.8330 - val_loss: 0.3317 - val_accuracy: 0.8503
# Epoch 43/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.3617 - accuracy: 0.8331 - val_loss: 0.3213 - val_accuracy: 0.8547
# Epoch 44/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.3403 - accuracy: 0.8403 - val_loss: 0.3235 - val_accuracy: 0.8524
# Epoch 45/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.3341 - accuracy: 0.8422 - val_loss: 0.3179 - val_accuracy: 0.8475
# Epoch 46/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.3278 - accuracy: 0.8453 - val_loss: 0.3277 - val_accuracy: 0.8415
# Epoch 47/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.3258 - accuracy: 0.8465 - val_loss: 0.3065 - val_accuracy: 0.8518
# Epoch 48/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.3464 - accuracy: 0.8375 - val_loss: 0.4007 - val_accuracy: 0.8096
# Epoch 49/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.3559 - accuracy: 0.8338 - val_loss: 0.3301 - val_accuracy: 0.8472
# Epoch 50/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.3291 - accuracy: 0.8430 - val_loss: 0.3164 - val_accuracy: 0.8467
# Epoch 51/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.3279 - accuracy: 0.8395 - val_loss: 0.3032 - val_accuracy: 0.8488
# Epoch 52/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.3196 - accuracy: 0.8420 - val_loss: 0.2978 - val_accuracy: 0.8550
# Epoch 53/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.3030 - accuracy: 0.8522 - val_loss: 0.2969 - val_accuracy: 0.8554
# Epoch 54/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.2978 - accuracy: 0.8500 - val_loss: 0.3075 - val_accuracy: 0.8391
# Epoch 55/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.2935 - accuracy: 0.8508 - val_loss: 0.3031 - val_accuracy: 0.8446
# Epoch 56/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.2907 - accuracy: 0.8553 - val_loss: 0.3121 - val_accuracy: 0.8390
# Epoch 57/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.2941 - accuracy: 0.8532 - val_loss: 0.2803 - val_accuracy: 0.8593
# Epoch 58/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.2964 - accuracy: 0.8521 - val_loss: 0.2743 - val_accuracy: 0.8711
# Epoch 59/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.2812 - accuracy: 0.8609 - val_loss: 0.2669 - val_accuracy: 0.8705
# Epoch 60/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.2918 - accuracy: 0.8638 - val_loss: 0.2796 - val_accuracy: 0.8642
# Epoch 61/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.2733 - accuracy: 0.8799 - val_loss: 0.2616 - val_accuracy: 0.8885
# Epoch 62/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.2685 - accuracy: 0.8896 - val_loss: 0.2585 - val_accuracy: 0.8983
# Epoch 63/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.2356 - accuracy: 0.9068 - val_loss: 0.3193 - val_accuracy: 0.8602
# Epoch 64/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.2456 - accuracy: 0.9025 - val_loss: 0.2315 - val_accuracy: 0.9091
# Epoch 65/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.2774 - accuracy: 0.8893 - val_loss: 0.3019 - val_accuracy: 0.8793
# Epoch 66/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.2605 - accuracy: 0.8976 - val_loss: 0.2237 - val_accuracy: 0.9113
# Epoch 67/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.2221 - accuracy: 0.9118 - val_loss: 0.2296 - val_accuracy: 0.9076
# Epoch 68/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.2070 - accuracy: 0.9178 - val_loss: 0.2027 - val_accuracy: 0.9154
# Epoch 69/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.2031 - accuracy: 0.9185 - val_loss: 0.1969 - val_accuracy: 0.9245
# Epoch 70/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.1921 - accuracy: 0.9236 - val_loss: 0.1815 - val_accuracy: 0.9277
# Epoch 71/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.1843 - accuracy: 0.9248 - val_loss: 0.2534 - val_accuracy: 0.9034
# Epoch 72/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.1779 - accuracy: 0.9307 - val_loss: 0.1614 - val_accuracy: 0.9362
# Epoch 73/100
# 23/23 [==============================] - 47s 2s/step - loss: 0.1751 - accuracy: 0.9303 - val_loss: 0.1663 - val_accuracy: 0.9341
# Epoch 74/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.1656 - accuracy: 0.9338 - val_loss: 0.1545 - val_accuracy: 0.9376
# Epoch 75/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.1714 - accuracy: 0.9302 - val_loss: 0.1844 - val_accuracy: 0.9284
# Epoch 76/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.1782 - accuracy: 0.9294 - val_loss: 0.1518 - val_accuracy: 0.9402
# Epoch 77/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.1509 - accuracy: 0.9401 - val_loss: 0.1478 - val_accuracy: 0.9413
# Epoch 78/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.1509 - accuracy: 0.9403 - val_loss: 0.1677 - val_accuracy: 0.9294
# Epoch 79/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.1450 - accuracy: 0.9426 - val_loss: 0.2260 - val_accuracy: 0.9058
# Epoch 80/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.1505 - accuracy: 0.9401 - val_loss: 0.1373 - val_accuracy: 0.9447
# Epoch 81/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.1372 - accuracy: 0.9452 - val_loss: 0.1393 - val_accuracy: 0.9439
# Epoch 82/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.1436 - accuracy: 0.9425 - val_loss: 0.1232 - val_accuracy: 0.9513
# Epoch 83/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.1320 - accuracy: 0.9479 - val_loss: 0.1204 - val_accuracy: 0.9526
# Epoch 84/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.2177 - accuracy: 0.9349 - val_loss: 1.9835 - val_accuracy: 0.2514
# Epoch 85/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.6135 - accuracy: 0.8056 - val_loss: 0.5267 - val_accuracy: 0.8215
# Epoch 86/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.5059 - accuracy: 0.8248 - val_loss: 0.4604 - val_accuracy: 0.8352
# Epoch 87/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.4838 - accuracy: 0.8203 - val_loss: 0.4710 - val_accuracy: 0.8165
# Epoch 88/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.4782 - accuracy: 0.8179 - val_loss: 0.4237 - val_accuracy: 0.8247
# Epoch 89/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.4312 - accuracy: 0.8222 - val_loss: 0.3945 - val_accuracy: 0.8384
# Epoch 90/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.4209 - accuracy: 0.8273 - val_loss: 0.3893 - val_accuracy: 0.8304
# Epoch 91/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.3983 - accuracy: 0.8331 - val_loss: 0.3812 - val_accuracy: 0.8377
# Epoch 92/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.3816 - accuracy: 0.8421 - val_loss: 0.3965 - val_accuracy: 0.8431
# Epoch 93/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.3848 - accuracy: 0.8413 - val_loss: 0.3601 - val_accuracy: 0.8441
# Epoch 94/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.3611 - accuracy: 0.8482 - val_loss: 0.3376 - val_accuracy: 0.8620
# Epoch 95/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.3205 - accuracy: 0.8690 - val_loss: 0.3320 - val_accuracy: 0.8608
# Epoch 96/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.3228 - accuracy: 0.8680 - val_loss: 0.3236 - val_accuracy: 0.8676
# Epoch 97/100
# 23/23 [==============================] - 46s 2s/step - loss: 0.3158 - accuracy: 0.8722 - val_loss: 0.2893 - val_accuracy: 0.8892
# Epoch 98/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.2864 - accuracy: 0.8861 - val_loss: 0.2819 - val_accuracy: 0.8859
# Epoch 99/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.2856 - accuracy: 0.8874 - val_loss: 0.2694 - val_accuracy: 0.8980
# Epoch 100/100
# 23/23 [==============================] - 45s 2s/step - loss: 0.2592 - accuracy: 0.8971 - val_loss: 0.2565 - val_accuracy: 0.8971

# %%
model.load_weights(checkpoint_filepath)

# %%
model.save(data_dir + "final_weights/")
# Out:
# WARNING:tensorflow:Skipping full serialization of Keras layer <models.VGG16.VGG16 object at 0x7fdcd65a7160>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fdcd65d3e48>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Flatten object at 0x7fdcd65d7128>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Dense object at 0x7fdcd65d72e8>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Dense object at 0x7fdcd65d7668>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <tensorflow.python.keras.layers.core.Dense object at 0x7fdcd65d79e8>, because it is not built.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/data/final_weights/assets
